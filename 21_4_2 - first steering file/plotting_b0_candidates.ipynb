# %% [markdown]
# # Plotting the distribution of the beam-constrained mass for the B0 candidates

# %%
import root_pandas
import matplotlib.pyplot as plt
# show plots in notebook
# %matplotlib inline
# set cool colours
plt.style.use('belle2')
# Out:
# Welcome to JupyROOT 6.20/04

# %% [markdown]
# ## Signal + Background

# %% [markdown]
# Import the results obtained by `b0_candidates` for the filenumber `filenumber`

# %%
# file to plot
filenumber = 1
filename = f"./Bd2JpsiKS_{filenumber}_without_cut.root"
# import to python
df = root_pandas.read_root(filename)
# Investigate ROOT file
df.describe()
# Out:
#        __experiment__  __run__     __event__  __candidate__  __ncandidates__  \
# count         67082.0  67082.0  67082.000000   67082.000000     67082.000000
# mean           1003.0      0.0  14990.758430      12.603918        26.207835
# std               0.0      0.0   2866.154677      20.755281        33.479544
# min            1003.0      0.0  10001.000000       0.000000         1.000000
# 25%            1003.0      0.0  12541.000000       2.000000         7.000000
# 50%            1003.0      0.0  15039.000000       5.000000        14.000000
# 75%            1003.0      0.0  17481.000000      14.000000        32.000000
# max            1003.0      0.0  19999.000000     251.000000       252.000000
#
#        __weight__            px            py            pz            pt  \
# count     67082.0  67082.000000  67082.000000  67082.000000  67082.000000
# mean          1.0      0.147540      0.009246      0.914087      1.182013
# std           0.0      0.953933      0.947589      0.989791      0.657717
# min           1.0     -9.177123     -8.269347     -2.762198      0.005765
# 25%           1.0     -0.467935     -0.601477      0.170700      0.640523
# 50%           1.0      0.151763      0.002525      0.908539      1.167040
# 75%           1.0      0.764037      0.617331      1.592330      1.634605
# max           1.0     11.486501      5.877742     18.367348     14.153508
#
#        ...          mcPT          mcPX          mcPY          mcPZ  \
# count  ...  63429.000000  63429.000000  63429.000000  63429.000000
# mean   ...      0.437527      0.414032      0.000334      2.725049
# std    ...      0.089262      0.132770      0.101722      0.594411
# min    ...      0.002885     -1.943631     -1.670254     -1.291828
# 25%    ...      0.456377      0.456357     -0.000000      2.991867
# 50%    ...      0.456601      0.456589     -0.000000      2.997746
# 75%    ...      0.456788      0.456774     -0.000000      3.002292
# max    ...      2.241446      1.977744      2.043980      3.167949
#
#               mcPhi      isSignal      mcErrors          mcPDG           Mbc  \
# count  63429.000000  63429.000000  67082.000000   63429.000000  67043.000000
# mean       0.001128      0.095997    392.539250  246461.467136      5.036916
# std        0.522252      0.294590    168.455551  115454.758756      0.216860
# min       -3.140838      0.000000      0.000000  -10413.000000      1.213624
# 25%       -0.000000      0.000000    314.500000  300553.000000      4.932220
# 50%       -0.000000      0.000000    432.000000  300553.000000      5.066574
# 75%       -0.000000      0.000000    444.000000  300553.000000      5.201683
# max        3.139461      1.000000   1534.000000  300553.000000      5.289778
#
#              deltaE
# count  67082.000000
# mean      -1.943382
# std        1.187822
# min       -4.583120
# 25%       -2.815894
# 50%       -1.869556
# 75%       -1.076289
# max       12.810844
#
# [8 rows x 24 columns]

# %% [markdown]
# Plot the distribution of the candidates taking advantage that this is MonteCarlo data and we know which candidates are actually `signal` (actual B0s) and which ones are `background`

# %%
# Plot histogram in 100 bins
df.Mbc.hist(range=(4.3, 5.3), bins=100, by=df.isSignal)
plt.xlabel(r'M$_{\rm bc}$ [GeV/c$^{2}$]')
plt.ylabel('Number of candidates')
# Out:
# Text(0, 0.5, 'Number of candidates')

# %% [markdown]
# ## Signal without Background
#
# After adding a cut to remove the background, we can run everything again to see only the data we want

# %%
filenumber = 1
filename = f"./Bd2JpsiKS_{filenumber}_with_cut.root"
# import to python
df2 = root_pandas.read_root(filename)
# Investigate ROOT file
df2
# Out:
#       __experiment__  __run__  __event__  __candidate__  __ncandidates__  \
# 0               1003        0      10001              0                1
# 1               1003        0      10006              0                1
# 2               1003        0      10007              0                1
# 3               1003        0      10009              0                1
# 4               1003        0      10011              0                1
# ...              ...      ...        ...            ...              ...
# 4245            1003        0      19986              0                1
# 4246            1003        0      19988              0                1
# 4247            1003        0      19996              0                1
# 4248            1003        0      19997              0                1
# 4249            1003        0      19999              0                1
#
#       __weight__        px        py        pz        pt  ...  \
# 0            1.0 -0.016916  0.117621  1.484648  0.118832  ...
# 1            1.0  0.064462 -0.084356  1.757974  0.106166  ...
# 2            1.0 -0.050813  0.097297  1.703138  0.109766  ...
# 3            1.0  0.450318  0.163054  1.737110  0.478929  ...
# 4            1.0 -0.013409  0.152206  1.709757  0.152796  ...
# ...          ...       ...       ...       ...       ...  ...
# 4245         1.0  0.408603 -0.017884  1.318997  0.408995  ...
# 4246         1.0 -0.041855 -0.115749  1.581955  0.123084  ...
# 4247         1.0  0.236869  0.317918  1.617495  0.396457  ...
# 4248         1.0 -0.107128  0.039043  1.511665  0.114021  ...
# 4249         1.0  0.478407 -0.154218  1.575416  0.502649  ...
#
#       nROE_Photons__bo__bc  nROE_NeutralHadrons__bo__bc  roeE__bomy_mask__bc  \
# 0                      5.0                          1.0             3.331398
# 1                     12.0                          1.0             5.212584
# 2                      7.0                          2.0             3.016505
# 3                     13.0                          3.0             5.340740
# 4                      7.0                          2.0             5.499140
# ...                    ...                          ...                  ...
# 4245                  10.0                          2.0             5.826196
# 4246                  12.0                          2.0             4.937091
# 4247                  13.0                          3.0             6.137547
# 4248                  10.0                          3.0             4.910660
# 4249                  14.0                          1.0             5.971081
#
#       roeM__bomy_mask__bc  roeP__bomy_mask__bc  roeMbc__bomy_mask__bc  \
# 0                3.006393             1.435204               4.974509
# 1                4.998348             1.479037               5.278048
# 2                2.941129             0.670118               5.174909
# 3                5.084607             1.634100               5.206438
# 4                5.325255             1.371932               5.277230
# ...                   ...                  ...                    ...
# 4245             5.003525             2.984844               5.078209
# 4246             4.582879             1.836324               5.240612
# 4247             5.695096             2.288093               5.245068
# 4248             4.724697             1.338587               5.242109
# 4249             5.665588             1.885450               5.234263
#
#       roeDeltae__bomy_mask__bc  nROE_Charged__bomy_mask__bc  \
# 0                    -1.786292                          2.0
# 1                    -0.279044                          5.0
# 2                    -2.150938                          2.0
# 3                    -0.119867                          6.0
# 4                     0.047912                          4.0
# ...                        ...                          ...
# 4245                 -0.071655                          9.0
# 4246                 -0.650757                          4.0
# 4247                  0.446521                          7.0
# 4248                 -0.512246                          7.0
# 4249                  0.427138                          4.0
#
#       nROE_Photons__bomy_mask__bc  nROE_NeutralHadrons__bomy_mask__bc
# 0                             2.0                                 1.0
# 1                            10.0                                 1.0
# 2                             5.0                                 2.0
# 3                            11.0                                 3.0
# 4                             3.0                                 2.0
# ...                           ...                                 ...
# 4245                          8.0                                 2.0
# 4246                          9.0                                 2.0
# 4247                         13.0                                 3.0
# 4248                          8.0                                 3.0
# 4249                         13.0                                 1.0
#
# [4250 rows x 258 columns]

# %%
# Plot histogram in 100 bins
df2.Mbc.hist(range=(4.3, 5.3), bins=100)
plt.xlabel(r'M$_{\rm bc}$ [GeV/c$^{2}$]')
plt.ylabel('Number of candidates')
# Out:
# Text(0, 0.5, 'Number of candidates')

# %% [markdown]
# # Plot ROE

# %%
m_bins = 50
m_range = (0, 10)
fig, ax = plt.subplots(1,2, figsize=(15, 7))
# Left subplot of ROE mass:
ax[0].hist(df2['roeM__bo__bc'], label='No mask',
           bins = m_bins, range=m_range, alpha=0.6)
ax[0].hist(df2['roeM__bomy_mask__bc'], label='"my_mask" applied',
           bins = m_bins, range=m_range, alpha=0.6)
ax[0].set_xlim(m_range)
ax[0].set_xlabel('ROE mass [GeV/$c^2$]')
# Right subplot of number of charged ROE particles:
m_bins = 15
m_range = (0, 15)
ax[1].hist(df2['nROE_Charged__bo__bc'], label='No mask',
           bins = m_bins, range=m_range, alpha=0.6)
ax[1].hist(df2['nROE_Charged__bomy_mask__bc'], label='"my_mask" applied',
           bins = m_bins, range=m_range, alpha=0.6)
ax[1].set_xlim(m_range)
ax[1].set_xlabel('# of charged ROE particles')
ax[1].legend()
fig.tight_layout()

# %% [markdown]
# The invariant mass distribution for masked ROE is much narrower and its mean is a little bit below nominal $B^0$ mass, contrary to the unmasked ROE distribution. This is expected, because a generic $B^0$ decay may produce particles, that are not accounted in ROE mass computation, like $K^0_L$ or neutrinos.
#
# The distribution of the number of charged particles for masked ROE has much more prominent peaks at 4 and 6 particles than its unmasked version, which corresponds to the fact that a correctly reconstructed $B^0$ will have an even number of charged daughter particles.
#
# This means that even a simple ROE mask like my_mask does a really good job of cleaning up the particles, which are not associated to the partner $B^0$.
